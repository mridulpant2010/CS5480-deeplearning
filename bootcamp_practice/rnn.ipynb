# %% [markdown]
# ## Sequence Unrolling
# - One can create a minimal recurrent unit by connecting the current timesteps’ output to the input of the next timestep!
# - the time and space complexity to produce the output of the RNN is asymptotically linear to the input length (timesteps)
# - gradient accumulation
#   -
